# %% [markdown]
# <a href="https://colab.research.google.com/github/LisithaDiz/ML/blob/main/Predict_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
data = pd.read_csv('/content/drive/MyDrive/ML csv/petrol_consumption.csv')

# %%
var = ['Petrol_tax',
       'Average_income',
       'Paved_Highways',
       'Population_Driver_licence(%)',]

for i in var:
    plt.figure()
    sns.regplot(x=i, y='Petrol_Consumption', data=data).set(title=f'Regression plot of {i} and Petrol Consumption')

# %%
correlations = data.corr()
sns.heatmap(correlations, annot=True).set(title="Heatmap")
# Out:
# [Text(0.5, 1.0, 'Heatmap')]

# %%
y = data['Petrol_Consumption']
X = data[['Petrol_tax',
          'Average_income',
          'Paved_Highways',
          'Population_Driver_licence(%)']]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)
reg = LinearRegression()s
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
print(X.columns)
cof_df = pd.DataFrame(data=reg.coef_,
                      index=X.columns,
                      columns=['Coefficient value'])
print(cof_df)
# Out:
# [-3.69937459e+01 -5.65355145e-02 -4.38217137e-03  1.34686930e+03]
# 361.45087906653225
# Index(['Petrol_tax', 'Average_income', 'Paved_Highways',
#        'Population_Driver_licence(%)'],
#       dtype='object')
#                               Coefficient value
# Petrol_tax                           -36.993746
# Average_income                        -0.056536
# Paved_Highways                        -0.004382
# Population_Driver_licence(%)        1346.869298

# %%
y_pred = reg.predict(X_test)
result = pd.DataFrame({'Actual' : y_test, 'Predicted' : y_pred})
print(result)
# Out:
#     Actual   Predicted
# 27     631  606.692665
# 40     587  673.779442
# 26     577  584.991490
# 43     591  563.536910
# 24     460  519.058672
# 37     704  643.461003
# 12     525  572.897614
# 19     640  687.077036
# 4      410  547.609366
# 25     566  530.037630

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean absolute error: {mae:.2f}')
print(f'Mean squared error: {mse:.2f}')
print(f'Root mean squared error: {rmse:.2f}')
print(reg.score(X_test, y_test))
print(reg.score(X_train, y_train))
# Out:
# Mean absolute error: 53.47
# Mean squared error: 4083.26
# Root mean squared error: 63.90
# 0.3913664001428886
# 0.7068781342155135
